# %%
import tifffile as tf
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
fname = r"F:\John\L6 Experiments\recordings_MDaxons\SH4_rec_img_002\img.tif"
img = tf.memmap(fname, mode='r')
img.shape
# Out:
# (1000, 512, 512)

# %%
plt.imshow(img[100])
