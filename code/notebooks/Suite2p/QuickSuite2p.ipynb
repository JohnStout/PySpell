# %% [markdown]
# Quick and easy suite2p

# %%
import os; import matplotlib.pyplot as plt; import tifffile as tf
path_added = os.path.split(os.path.split(os.getcwd())[0])[0]; os.chdir(path_added); print("Added path:",path_added)
import s2pfuns

import rootfun as rf # we can import this if our cwd is local
root = rf.dropbox_root(dropbox_folder='timspellman')
# Out:
# Added path: c:\Users\spell\SpellmanLab Dropbox\timspellman\Python\John\PySpell\code

# %% [markdown]
# Change the following variables and run the cell
#
#     imgpath: path to your data
#     savepath: place to save your data - will be updated and defined based on the imgpath
#     gcamp: if 6f or 8f, just write '6f'

# %%
imgpath  = r"C:\Users\spell\SpellmanLab Dropbox\OtherData\John\ProjectData\project_CT_layer6\layer6stim_L5rec\L6-05\HB3_expressionCheck_001\img.tif"
savepath = os.path.split(imgpath)[0]
gcamp    = '6f'

# Don't change
session  = os.path.split(os.path.split(imgpath)[0])[-1]
savepath = os.path.join(savepath,session)
try: os.mkdir(savepath); 
except: pass
print("Running suite2p and saving to:",savepath)

# run s2p
s2pfuns.fast_suite2p(imgpath=imgpath, savepath='', gcamp=gcamp)
# Out:
# Running suite2p and saving to: C:\Users\spell\SpellmanLab Dropbox\OtherData\John\ProjectData\project_CT_layer6\layer6stim_L5rec\L6-05\HB3_expressionCheck_001\HB3_expressionCheck_001
# {'data_path': ['C:\\Users\\spell\\SpellmanLab Dropbox\\OtherData\\John\\ProjectData\\project_CT_layer6\\layer6stim_L5rec\\L6-05\\HB3_expressionCheck_001'], 'tiff_list': ['img.tif']}
# tif
# ** Found 1 tifs - converting to binary **
# 2000 frames of binary, time 5.90 sec.
# time 6.35 sec. Wrote 2131 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# NOTE: applying default C:\Users\spell\.suite2p\classifiers\classifier_user.npy
# ----------- REGISTRATION
# Reference frame, 8.83 sec.
# Registered 500/2131 in 7.17s
# Registered 1000/2131 in 14.17s
# Registered 1500/2131 in 21.66s
# Registered 2000/2131 in 28.50s
# Registered 2131/2131 in 30.23s
# ...
