# %%
import tifffile as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
fname = r"F:\John\L6 Experiments\recordings_panneuronal\L6-02\sessions\SD1_whisker_d1\img\Image_001_001.raw"
img = np.memmap(fname, mode='r')
img.shape
# Out:
# (125829120000,)

# %%
plt.imshow(img[0])

# %% [markdown]
# Weird conversion issue

# %%
import os; import matplotlib.pyplot as plt; import tifffile as tf
path_added = os.path.split(os.path.split(os.getcwd())[0])[0]; os.chdir(path_added); print("Added path:",path_added)
import thorfuns
# Out:
# Added path: c:\Users\spell\SpellmanLab Dropbox\timspellman\Python\John\PySpell\code

# %%
# max_proj didn't solve high memory demands, testing why my file is weird when converting with matlab
# slow
fname = r"F:\John\L6 Experiments\recordings_panneuronal\L6-02\sessions\SD1_whisker_d1\img\Image_001_001.raw"
thorfuns.RawToTif(filepath=fname).convert(method='max_proj')
# Out:
# Starting at 18.0 <%> RAM utility
# rootpath: F:\John\L6 Experiments\recordings_panneuronal\L6-02\sessions\SD1_whisker_d1\img
# This code does not support multi-channel recordings
# Starting at 18.0 <%> RAM utility
# method: max_proj detected. Your file will be saved with dimensions (t,y,x): 60000 512 512
# Please wait while memory mapped file is created...
# c:\Users\spell\anaconda3\envs\suite2p\lib\site-packages\tifffile\tifffile.py:3607: UserWarning: <tifffile.TiffWriter 'img_mmap_maxproj_z.tif'> truncating ImageJ file
#   warnings.warn(
# 4.640625
# Update: 18.0 <%> RAM utility
# Run time for 0 / 60000 : 53.4375 Memory: 18.2 <%> RAM utility
# Run time for 500 / 60000 : 54.5625 Memory: 18.3 <%> RAM utility
# Run time for 1000 / 60000 : 56.0 Memory: 18.5 <%> RAM utility
# Run time for 1500 / 60000 : 57.296875 Memory: 18.6 <%> RAM utility
# Run time for 2000 / 60000 : 58.5625 Memory: 18.8 <%> RAM utility
# Run time for 2500 / 60000 : 59.78125 Memory: 18.9 <%> RAM utility
# Run time for 3000 / 60000 : 61.015625 Memory: 19.0 <%> RAM utility
# Run time for 3500 / 60000 : 62.1875 Memory: 19.2 <%> RAM utility
# Run time for 4000 / 60000 : 63.46875 Memory: 19.3 <%> RAM utility
# Run time for 4500 / 60000 : 64.71875 Memory: 19.5 <%> RAM utility
# Run time for 5000 / 60000 : 65.8125 Memory: 19.6 <%> RAM utility
# Run time for 5500 / 60000 : 66.953125 Memory: 19.8 <%> RAM utility
# Run time for 6000 / 60000 : 68.1875 Memory: 19.9 <%> RAM utility
# Run time for 6500 / 60000 : 69.390625 Memory: 20.1 <%> RAM utility
# Run time for 7000 / 60000 : 70.765625 Memory: 20.2 <%> RAM utility
# Run time for 7500 / 60000 : 71.796875 Memory: 20.3 <%> RAM utility
# Run time for 8000 / 60000 : 73.015625 Memory: 20.5 <%> RAM utility
# Run time for 8500 / 60000 : 74.390625 Memory: 20.6 <%> RAM utility
# Run time for 9000 / 60000 : 75.71875 Memory: 20.8 <%> RAM utility
# Run time for 9500 / 60000 : 77.109375 Memory: 20.9 <%> RAM utility
# Run time for 10000 / 60000 : 78.25 Memory: 21.1 <%> RAM utility
# Run time for 10500 / 60000 : 79.515625 Memory: 21.2 <%> RAM utility
# Run time for 11000 / 60000 : 80.890625 Memory: 21.3 <%> RAM utility
# Run time for 11500 / 60000 : 82.015625 Memory: 21.5 <%> RAM utility
# Run time for 12000 / 60000 : 83.15625 Memory: 21.6 <%> RAM utility
# Run time for 12500 / 60000 : 84.34375 Memory: 21.8 <%> RAM utility
# Run time for 13000 / 60000 : 85.53125 Memory: 21.9 <%> RAM utility
# Run time for 13500 / 60000 : 86.78125 Memory: 22.1 <%> RAM utility
# Run time for 14000 / 60000 : 87.96875 Memory: 22.2 <%> RAM utility
# Run time for 14500 / 60000 : 89.3125 Memory: 22.4 <%> RAM utility
# Run time for 15000 / 60000 : 90.5 Memory: 22.5 <%> RAM utility
# Run time for 15500 / 60000 : 91.671875 Memory: 22.6 <%> RAM utility
# Run time for 16000 / 60000 : 92.78125 Memory: 22.8 <%> RAM utility
# Run time for 16500 / 60000 : 94.046875 Memory: 22.9 <%> RAM utility
# Run time for 17000 / 60000 : 95.25 Memory: 23.1 <%> RAM utility
# Run time for 17500 / 60000 : 96.515625 Memory: 23.2 <%> RAM utility
# Run time for 18000 / 60000 : 97.59375 Memory: 23.4 <%> RAM utility
# Run time for 18500 / 60000 : 98.765625 Memory: 23.5 <%> RAM utility
# Run time for 19000 / 60000 : 100.171875 Memory: 23.6 <%> RAM utility
# Run time for 19500 / 60000 : 101.40625 Memory: 23.8 <%> RAM utility
# Run time for 20000 / 60000 : 102.625 Memory: 23.9 <%> RAM utility
# Run time for 20500 / 60000 : 103.859375 Memory: 24.1 <%> RAM utility
# Run time for 21000 / 60000 : 105.265625 Memory: 24.2 <%> RAM utility
# Run time for 21500 / 60000 : 106.578125 Memory: 24.4 <%> RAM utility
# Run time for 22000 / 60000 : 107.859375 Memory: 24.5 <%> RAM utility
# Run time for 22500 / 60000 : 109.03125 Memory: 24.7 <%> RAM utility
# Run time for 23000 / 60000 : 110.125 Memory: 24.8 <%> RAM utility
# Run time for 23500 / 60000 : 111.265625 Memory: 24.9 <%> RAM utility
# Run time for 24000 / 60000 : 112.515625 Memory: 25.1 <%> RAM utility
# Run time for 24500 / 60000 : 113.734375 Memory: 25.2 <%> RAM utility
# Run time for 25000 / 60000 : 114.921875 Memory: 25.4 <%> RAM utility
# Run time for 25500 / 60000 : 116.078125 Memory: 25.5 <%> RAM utility
# Run time for 26000 / 60000 : 117.3125 Memory: 25.7 <%> RAM utility
# Run time for 26500 / 60000 : 118.5 Memory: 25.8 <%> RAM utility
# Run time for 27000 / 60000 : 119.796875 Memory: 25.9 <%> RAM utility
# Run time for 27500 / 60000 : 121.15625 Memory: 26.1 <%> RAM utility
# Run time for 28000 / 60000 : 122.453125 Memory: 26.2 <%> RAM utility
# Run time for 28500 / 60000 : 123.8125 Memory: 26.4 <%> RAM utility
# Run time for 29000 / 60000 : 125.0 Memory: 26.5 <%> RAM utility
# Run time for 29500 / 60000 : 126.3125 Memory: 26.7 <%> RAM utility
# Run time for 30000 / 60000 : 127.578125 Memory: 26.8 <%> RAM utility
# Run time for 30500 / 60000 : 128.734375 Memory: 26.9 <%> RAM utility
# Run time for 31000 / 60000 : 130.09375 Memory: 27.1 <%> RAM utility
# Run time for 31500 / 60000 : 131.3125 Memory: 27.2 <%> RAM utility
# Run time for 32000 / 60000 : 132.625 Memory: 27.4 <%> RAM utility
# Run time for 32500 / 60000 : 134.015625 Memory: 27.5 <%> RAM utility
# Run time for 33000 / 60000 : 135.25 Memory: 27.7 <%> RAM utility
# Run time for 33500 / 60000 : 136.46875 Memory: 27.8 <%> RAM utility
# Run time for 34000 / 60000 : 137.671875 Memory: 27.9 <%> RAM utility
# Run time for 34500 / 60000 : 138.953125 Memory: 28.1 <%> RAM utility
# Run time for 35000 / 60000 : 140.25 Memory: 28.2 <%> RAM utility
# Run time for 35500 / 60000 : 141.453125 Memory: 28.4 <%> RAM utility
# Run time for 36000 / 60000 : 142.625 Memory: 28.5 <%> RAM utility
# Run time for 36500 / 60000 : 144.09375 Memory: 28.7 <%> RAM utility
# Run time for 37000 / 60000 : 145.3125 Memory: 28.8 <%> RAM utility
# Run time for 37500 / 60000 : 146.546875 Memory: 29.0 <%> RAM utility
# Run time for 38000 / 60000 : 147.984375 Memory: 29.1 <%> RAM utility
# Run time for 38500 / 60000 : 149.296875 Memory: 29.2 <%> RAM utility
# Run time for 39000 / 60000 : 150.546875 Memory: 29.4 <%> RAM utility
# Run time for 39500 / 60000 : 151.90625 Memory: 29.5 <%> RAM utility
# Run time for 40000 / 60000 : 153.28125 Memory: 29.7 <%> RAM utility
# Run time for 40500 / 60000 : 154.5625 Memory: 29.8 <%> RAM utility
# Run time for 41000 / 60000 : 156.078125 Memory: 30.0 <%> RAM utility
# Run time for 41500 / 60000 : 157.515625 Memory: 30.1 <%> RAM utility
# Run time for 42000 / 60000 : 158.875 Memory: 30.3 <%> RAM utility
