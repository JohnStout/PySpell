# %%
import os; import matplotlib.pyplot as plt
path_added = os.path.split(os.path.split(os.getcwd())[0])[0]; os.chdir(path_added); print("Added path:",path_added)

import s2pfuns
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
# Out:
# Added path: c:\Users\johnj\SpellmanLab Dropbox\timspellman\Python\John\PySpell\code

# %%
fpath = r"C:\Users\johnj\SpellmanLab Dropbox\OtherData\John\EXPERIMENTS\LAYER6\Corticocortical\L6E04_M_LeftPFC_L6Chr_PFCgcamp6f\FOV1\SD1_odor_day1_FOV1_optoRec"
F, Fneu, spks, stat, ops, iscell, blF = s2pfuns.read_s2p(fpath=fpath)
f0 = s2pfuns.baselineF(fpath=fpath, baseline = "constant_prctile")
Ff0 = F/f0
Fbl = s2pfuns.baseline_corrected_F(F, Fneu, ops)
beh = sio.readmat()

# %%
plt.plot(Fbl[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.plot(Fbl[0])
#
# NameError: name 'plt' is not defined
