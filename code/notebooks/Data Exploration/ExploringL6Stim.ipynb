# %%
import os; import matplotlib.pyplot as plt
path_added = os.path.split(os.path.split(os.getcwd())[0])[0]; os.chdir(path_added); print("Added path:",path_added)

import s2pfuns
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
# Out:
# Added path: c:\Users\spell\SpellmanLab Dropbox\timspellman\Python\John\PySpell\code

# %%
fpath = r"E:\L6 Experiments\L612\FOV1\SEDS_day10_optoRec_LBC2_FOV1_p70\SEDS_day10_optoRec_LBC2_FOV1_p70_img\suite2p\plane0"
F, Fneu, spks, stat, ops, iscell, blF = s2pfuns.read_s2p(fpath=fpath)

# %%
stat.shape
F.shape
# Out:
# (310, 60000)

# %%
f0 = s2pfuns.baselineF(fpath=fpath, baseline = "constant_prctile")
Ff0 = F/f0
Fbl = s2pfuns.baseline_corrected_F(F, Fneu, ops)
beh = sio.readmat()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 4
#       2 Ff0 = F/f0
#       3 Fbl = s2pfuns.baseline_corrected_F(F, Fneu, ops)
# ----> 4 beh = sio.readmat()
#
# AttributeError: module 'scipy.io' has no attribute 'readmat'

# %%
plt.plot(Fbl[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.plot(Fbl[0])
#
# NameError: name 'plt' is not defined
